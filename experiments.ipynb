# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv

load_dotenv()

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", api_key="AIzaSyDGGF9cfSxmTRm3hmNdsi6xIf6m7uBzbsY",max_tokens=100)
response = llm.invoke("Recommend me a great sci-fi movie.")
print(response.content)
# Out:
# Okay, "great sci-fi" is a wonderful rabbit hole! To give you a fantastic recommendation, I'll offer a few diverse options, each considered a masterpiece for different reasons.
#
# **My Top Pick for a Modern, Thought-Provoking Experience:**
#
# 1.  **Arrival (2016)**
#     *   **Why it's great:** This film redefines the "first contact" genre. It's less about explosions and more about communication, language, and the profound impact of understanding. It's incredibly intelligent, deeply emotional, and features stunning visuals and a brilliant lead performance by Amy Adams. It leaves you thinking long after it's over.
#     *   **Vibe:** Meditative, intelligent, emotional, philosophical.
#
# **Other Legendary Options, Depending on Your Mood:**
#
# 2.  **Blade Runner (1982) / Blade Runner 2049 (2017)**
# ...
